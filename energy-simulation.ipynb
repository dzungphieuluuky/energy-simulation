# %%
# !python /kaggle/input/my-energy-simulation/train_with_model_selection.py
# Out:
# 2025-11-02 17:21:18.993790: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762104079.023221     115 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762104079.031878     115 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Starting Stable Baselines3 5G Agent Training...
# Using device: cpu
# Max cells: 57, Parallel envs: 5
# Traceback (most recent call last):
#   File "/kaggle/input/my-energy-simulation/train_with_model_selection.py", line 159, in <module>
#     scenario_files = [f for f in os.listdir(scenario_folder) if f.endswith('.json')]
# ...
