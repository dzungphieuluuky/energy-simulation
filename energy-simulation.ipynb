# %%
# !cd /kaggle/input/my-energy-simulation

# %%
# !python train_with_model_selection.py
# Out:
# python3: can't open file '/kaggle/working/train_with_model_selection.py': [Errno 2] No such file or directory
